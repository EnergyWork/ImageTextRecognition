# %%
import numpy as np
import cv2
import os
# %matplotlib inline 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
cv2.IMREAD_GRAYSCALE
# Out:
# 0

# %%
img = cv2.imread('images_dataset1/Train/img1018.jpg', cv2.IMREAD_GRAYSCALE)
print('Image Dimensions :', img.shape)
#img = cv.medianBlur(img,5)
img = cv2.bilateralFilter(img, 15, 80, 80)

ret, th1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
th3 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)

#titles = ['Original Image', 'Global Thresholding (v = 127)', 'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
# Out:
# Image Dimensions : (570, 500)

# %%
blur = cv2.GaussianBlur(img, (5,5), 0)
ret4, th4 = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
path = 'D:\\StudyMagistracy\\CourseProject\\data\\output\\outblur.jpeg'
save = cv2.imwrite(path, th4)
plt.imshow(th4, 'gray')

# %%
plt.imshow(images[0], 'gray')
plt.title(titles[0])
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
plt.imshow(images[1], 'gray')
plt.title(titles[1])
path = 'D:\\StudyMagistracy\\CourseProject\\data\\output\\outblurWithoutOtsu.jpeg'
save = cv2.imwrite(path, images[1])

# %%
plt.imshow(images[2], 'gray')
plt.title(titles[2])
path = 'D:\\StudyMagistracy\\CourseProject\\data\\output\\outamt.jpeg'
save = cv2.imwrite(path, images[2])

# %%
plt.imshow(images[3], 'gray')
plt.title(titles[3])
path = 'D:\\StudyMagistracy\\CourseProject\\data\\output\\outagt.jpeg'
save = cv2.imwrite(path, images[3])
